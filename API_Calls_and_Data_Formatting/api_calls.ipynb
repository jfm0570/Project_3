# %%
# Import Dependencies

import requests
import json
from config import api_key
from pprint import pprint
import pandas as pd

# %%
# Create urls
chicago_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Chicago/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
newyork_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/New%20York/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
losangeles_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Los%20Angeles/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
houston_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Houston/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
atlanta_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Atlanta/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
miami_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Miami/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
minneapolis_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Minneapolis/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
kansascity_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Kansas%20City/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
denver_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Denver/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
seattle_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Seattle/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
sanfrancisco_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/San%20Francisco/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="
phoenix_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Phoenix/2023-05-01/2023-07-31?unitGroup=us&include=days%2Calerts&key="

# %%
# Get responses and store data

chicago_response = requests.get(chicago_url + api_key)
pprint(chicago_response)
chicago_data = chicago_response.json()
newyork_response = requests.get(newyork_url + api_key)
pprint(newyork_response)
newyork_data = newyork_response.json()
losangeles_response = requests.get(losangeles_url + api_key)
pprint(losangeles_response)
losangeles_data = losangeles_response.json()
houston_response = requests.get(houston_url + api_key)
pprint(houston_response)
houston_data = houston_response.json()
atlanta_response = requests.get(atlanta_url + api_key)
pprint(atlanta_response)
atlanta_data = atlanta_response.json()
miami_response = requests.get(miami_url + api_key)
pprint(miami_response)
miami_data = miami_response.json()
minneapolis_response = requests.get(minneapolis_url + api_key)
pprint(minneapolis_response)
minneapolis_data = minneapolis_response.json()
kansascity_response = requests.get(kansascity_url + api_key)
pprint(kansascity_response)
kansascity_data = kansascity_response.json()
denver_response = requests.get(denver_url + api_key)
pprint(denver_response)
denver_data = denver_response.json()
seattle_response = requests.get(seattle_url + api_key)
pprint(seattle_response)
seattle_data = seattle_response.json()
sanfrancisco_response = requests.get(sanfrancisco_url + api_key)
pprint(sanfrancisco_response)
sanfrancisco_data = sanfrancisco_response.json()
phoenix_response = requests.get(phoenix_url + api_key)
pprint(phoenix_response)
phoenix_data = phoenix_response.json()
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
pprint(chicago_data)
# Out:
# {'address': 'Chicago',
#  'days': [{'cloudcover': 98.8,
#            'conditions': 'Rain, Overcast',
#            'datetime': '2023-05-01',
#            'datetimeEpoch': 1682917200,
#            'description': 'Cloudy skies throughout the day with rain in the '
#                           'morning and afternoon.',
#            'dew': 35.7,
#            'feelslike': 36.7,
#            'feelslikemax': 44.3,
#            'feelslikemin': 32.0,
#            'humidity': 72.9,
#            'icon': 'rain',
#            'moonphase': 0.37,
#            'precip': 0.068,
#            'precipcover': 33.33,
#            'precipprob': 100.0,
#            'preciptype': ['rain'],
#            'pressure': 997.4,
#            'severerisk': 10.0,
#            'snow': 0.0,
#            'snowdepth': 0.0,
#            'solarenergy': 3.3,
#            'solarradiation': 37.3,
#            'source': 'obs',
#            'stations': ['72534014819',
#                         'KORD',
# ...

# %%
# Create list to store data.
full_data = []

# %%
# Parse desired data from each city and append into data lists
# 92 days from May 1 to July 31

# Chicago

for x in range(92): 
    chicago_city = chicago_data["address"]
    chicago_cloudcover = chicago_data["days"][x]["cloudcover"]
    chicago_conditions = chicago_data["days"][x]["conditions"]
    chicago_datetime = chicago_data["days"][x]["datetime"]
    chicago_description = chicago_data["days"][x]["description"]
    chicago_dew = chicago_data["days"][x]["dew"]
    chicago_feelslike = chicago_data["days"][x]["feelslike"]
    chicago_feelslikemin = chicago_data["days"][x]["feelslikemin"]
    chicago_feelslikemax = chicago_data["days"][x]["feelslikemax"]
    chicago_humidity = chicago_data["days"][x]["humidity"]
    chicago_moonphase = chicago_data["days"][x]["moonphase"]
    chicago_precip = chicago_data["days"][x]["precip"]
    chicago_preciptype = chicago_data["days"][x]["preciptype"]
    chicago_pressure = chicago_data["days"][x]["pressure"]
    chicago_severerisk = chicago_data["days"][x]["severerisk"]
    chicago_sunrise = chicago_data["days"][x]["sunrise"]
    chicago_sunset = chicago_data["days"][x]["sunset"]
    chicago_temp = chicago_data["days"][x]["temp"]
    chicago_tempmax = chicago_data["days"][x]["tempmax"]
    chicago_tempmin = chicago_data["days"][x]["tempmin"]
    chicago_uv_index = chicago_data["days"][x]["uvindex"]
    chicago_visibility = chicago_data["days"][x]["visibility"]
    chicago_winddir = chicago_data["days"][x]["winddir"]
    chicago_windgust = chicago_data["days"][x]["windgust"]
    chicago_windspeed = chicago_data["days"][x]["windspeed"]

    full_data.append({"city": chicago_city,
                  "date": chicago_datetime,
                  "conditions": chicago_conditions,
                  "description": chicago_description,
                  "cloudcover": chicago_cloudcover,
                  "dewpoint": chicago_dew,
                  "pressure": chicago_pressure,
                  "humidity": chicago_humidity,
                  "uv_index": chicago_uv_index,
                  "visibility": chicago_visibility,
                  "feelslike": chicago_feelslike,
                  "feelslikemin": chicago_feelslikemin,
                  "feelslikemax": chicago_feelslikemax,
                  "temp": chicago_temp,
                  "tempmin": chicago_tempmin,
                  "tempmax": chicago_tempmax,
                  "precipitation": chicago_precip,
                  "precipitation_type": chicago_preciptype,
                  "wind_direction": chicago_winddir,
                  "wind_speed": chicago_windspeed,
                  "wind_gust": chicago_windgust,
                  "severe_risk": chicago_severerisk,
                  "moonphase": chicago_moonphase,
                  "sunrise": chicago_sunrise,
                  "sunset": chicago_sunset
                  })

# %%
# New York

for x in range(92): 
    newyork_city = newyork_data["address"]
    newyork_cloudcover = newyork_data["days"][x]["cloudcover"]
    newyork_conditions = newyork_data["days"][x]["conditions"]
    newyork_datetime = newyork_data["days"][x]["datetime"]
    newyork_description = newyork_data["days"][x]["description"]
    newyork_dew = newyork_data["days"][x]["dew"]
    newyork_feelslike = newyork_data["days"][x]["feelslike"]
    newyork_feelslikemin = newyork_data["days"][x]["feelslikemin"]
    newyork_feelslikemax = newyork_data["days"][x]["feelslikemax"]
    newyork_humidity = newyork_data["days"][x]["humidity"]
    newyork_moonphase = newyork_data["days"][x]["moonphase"]
    newyork_precip = newyork_data["days"][x]["precip"]
    newyork_preciptype = newyork_data["days"][x]["preciptype"]
    newyork_pressure = newyork_data["days"][x]["pressure"]
    newyork_severerisk = newyork_data["days"][x]["severerisk"]
    newyork_sunrise = newyork_data["days"][x]["sunrise"]
    newyork_sunset = newyork_data["days"][x]["sunset"]
    newyork_temp = newyork_data["days"][x]["temp"]
    newyork_tempmax = newyork_data["days"][x]["tempmax"]
    newyork_tempmin = newyork_data["days"][x]["tempmin"]
    newyork_uv_index = newyork_data["days"][x]["uvindex"]
    newyork_visibility = newyork_data["days"][x]["visibility"]
    newyork_winddir = newyork_data["days"][x]["winddir"]
    newyork_windgust = newyork_data["days"][x]["windgust"]
    newyork_windspeed = newyork_data["days"][x]["windspeed"]

    full_data.append({"city": newyork_city,
                  "date": newyork_datetime,
                  "conditions": newyork_conditions,
                  "description": newyork_description,
                  "cloudcover": newyork_cloudcover,
                  "dewpoint": newyork_dew,
                  "pressure": newyork_pressure,
                  "humidity": newyork_humidity,
                  "uv_index": newyork_uv_index,
                  "visibility": newyork_visibility,
                  "feelslike": newyork_feelslike,
                  "feelslikemin": newyork_feelslikemin,
                  "feelslikemax": newyork_feelslikemax,
                  "temp": newyork_temp,
                  "tempmin": newyork_tempmin,
                  "tempmax": newyork_tempmax,
                  "precipitation": newyork_precip,
                  "precipitation_type": newyork_preciptype,
                  "wind_direction": newyork_winddir,
                  "wind_speed": newyork_windspeed,
                  "wind_gust": newyork_windgust,
                  "severe_risk": newyork_severerisk,
                  "moonphase": newyork_moonphase,
                  "sunrise": newyork_sunrise,
                  "sunset": newyork_sunset
                  })

# %%
# Los Angeles
for x in range(92): 
    losangeles_city = losangeles_data["address"]
    losangeles_cloudcover = losangeles_data["days"][x]["cloudcover"]
    losangeles_conditions = losangeles_data["days"][x]["conditions"]
    losangeles_datetime = losangeles_data["days"][x]["datetime"]
    losangeles_description = losangeles_data["days"][x]["description"]
    losangeles_dew = losangeles_data["days"][x]["dew"]
    losangeles_feelslike = losangeles_data["days"][x]["feelslike"]
    losangeles_feelslikemin = losangeles_data["days"][x]["feelslikemin"]
    losangeles_feelslikemax = losangeles_data["days"][x]["feelslikemax"]
    losangeles_humidity = losangeles_data["days"][x]["humidity"]
    losangeles_moonphase = losangeles_data["days"][x]["moonphase"]
    losangeles_precip = losangeles_data["days"][x]["precip"]
    losangeles_preciptype = losangeles_data["days"][x]["preciptype"]
    losangeles_pressure = losangeles_data["days"][x]["pressure"]
    losangeles_severerisk = losangeles_data["days"][x]["severerisk"]
    losangeles_sunrise = losangeles_data["days"][x]["sunrise"]
    losangeles_sunset = losangeles_data["days"][x]["sunset"]
    losangeles_temp = losangeles_data["days"][x]["temp"]
    losangeles_tempmax = losangeles_data["days"][x]["tempmax"]
    losangeles_tempmin = losangeles_data["days"][x]["tempmin"]
    losangeles_uv_index = losangeles_data["days"][x]["uvindex"]
    losangeles_visibility = losangeles_data["days"][x]["visibility"]
    losangeles_winddir = losangeles_data["days"][x]["winddir"]
    losangeles_windgust = losangeles_data["days"][x]["windgust"]
    losangeles_windspeed = losangeles_data["days"][x]["windspeed"]

    full_data.append({"city": losangeles_city,
                  "date": losangeles_datetime,
                  "conditions": losangeles_conditions,
                  "description": losangeles_description,
                  "cloudcover": losangeles_cloudcover,
                  "dewpoint": losangeles_dew,
                  "pressure": losangeles_pressure,
                  "humidity": losangeles_humidity,
                  "uv_index": losangeles_uv_index,
                  "visibility": losangeles_visibility,
                  "feelslike": losangeles_feelslike,
                  "feelslikemin": losangeles_feelslikemin,
                  "feelslikemax": losangeles_feelslikemax,
                  "temp": losangeles_temp,
                  "tempmin": losangeles_tempmin,
                  "tempmax": losangeles_tempmax,
                  "precipitation": losangeles_precip,
                  "precipitation_type": losangeles_preciptype,
                  "wind_direction": losangeles_winddir,
                  "wind_speed": losangeles_windspeed,
                  "wind_gust": losangeles_windgust,
                  "severe_risk": losangeles_severerisk,
                  "moonphase": losangeles_moonphase,
                  "sunrise": losangeles_sunrise,
                  "sunset": losangeles_sunset
                  })

# %%
# Atlanta

for x in range(92): 
    atlanta_city = atlanta_data["address"]
    atlanta_cloudcover = atlanta_data["days"][x]["cloudcover"]
    atlanta_conditions = atlanta_data["days"][x]["conditions"]
    atlanta_datetime = atlanta_data["days"][x]["datetime"]
    atlanta_description = atlanta_data["days"][x]["description"]
    atlanta_dew = atlanta_data["days"][x]["dew"]
    atlanta_feelslike = atlanta_data["days"][x]["feelslike"]
    atlanta_feelslikemin = atlanta_data["days"][x]["feelslikemin"]
    atlanta_feelslikemax = atlanta_data["days"][x]["feelslikemax"]
    atlanta_humidity = atlanta_data["days"][x]["humidity"]
    atlanta_moonphase = atlanta_data["days"][x]["moonphase"]
    atlanta_precip = atlanta_data["days"][x]["precip"]
    atlanta_preciptype = atlanta_data["days"][x]["preciptype"]
    atlanta_pressure = atlanta_data["days"][x]["pressure"]
    atlanta_severerisk = atlanta_data["days"][x]["severerisk"]
    atlanta_sunrise = atlanta_data["days"][x]["sunrise"]
    atlanta_sunset = atlanta_data["days"][x]["sunset"]
    atlanta_temp = atlanta_data["days"][x]["temp"]
    atlanta_tempmax = atlanta_data["days"][x]["tempmax"]
    atlanta_tempmin = atlanta_data["days"][x]["tempmin"]
    atlanta_uv_index = atlanta_data["days"][x]["uvindex"]
    atlanta_visibility = atlanta_data["days"][x]["visibility"]
    atlanta_winddir = atlanta_data["days"][x]["winddir"]
    atlanta_windgust = atlanta_data["days"][x]["windgust"]
    atlanta_windspeed = atlanta_data["days"][x]["windspeed"]

    full_data.append({"city": atlanta_city,
                  "date": atlanta_datetime,
                  "conditions": atlanta_conditions,
                  "description": atlanta_description,
                  "cloudcover": atlanta_cloudcover,
                  "dewpoint": atlanta_dew,
                  "pressure": atlanta_pressure,
                  "humidity": atlanta_humidity,
                  "uv_index": atlanta_uv_index,
                  "visibility": atlanta_visibility,
                  "feelslike": atlanta_feelslike,
                  "feelslikemin": atlanta_feelslikemin,
                  "feelslikemax": atlanta_feelslikemax,
                  "temp": atlanta_temp,
                  "tempmin": atlanta_tempmin,
                  "tempmax": atlanta_tempmax,
                  "precipitation": atlanta_precip,
                  "precipitation_type": atlanta_preciptype,
                  "wind_direction": atlanta_winddir,
                  "wind_speed": atlanta_windspeed,
                  "wind_gust": atlanta_windgust,
                  "severe_risk": atlanta_severerisk,
                  "moonphase": atlanta_moonphase,
                  "sunrise": atlanta_sunrise,
                  "sunset": atlanta_sunset
                  })

# %%
# Miami

for x in range(92): 
    miami_city = miami_data["address"]
    miami_cloudcover = miami_data["days"][x]["cloudcover"]
    miami_conditions = miami_data["days"][x]["conditions"]
    miami_datetime = miami_data["days"][x]["datetime"]
    miami_description = miami_data["days"][x]["description"]
    miami_dew = miami_data["days"][x]["dew"]
    miami_feelslike = miami_data["days"][x]["feelslike"]
    miami_feelslikemin = miami_data["days"][x]["feelslikemin"]
    miami_feelslikemax = miami_data["days"][x]["feelslikemax"]
    miami_humidity = miami_data["days"][x]["humidity"]
    miami_moonphase = miami_data["days"][x]["moonphase"]
    miami_precip = miami_data["days"][x]["precip"]
    miami_preciptype = miami_data["days"][x]["preciptype"]
    miami_pressure = miami_data["days"][x]["pressure"]
    miami_severerisk = miami_data["days"][x]["severerisk"]
    miami_sunrise = miami_data["days"][x]["sunrise"]
    miami_sunset = miami_data["days"][x]["sunset"]
    miami_temp = miami_data["days"][x]["temp"]
    miami_tempmax = miami_data["days"][x]["tempmax"]
    miami_tempmin = miami_data["days"][x]["tempmin"]
    miami_uv_index = miami_data["days"][x]["uvindex"]
    miami_visibility = miami_data["days"][x]["visibility"]
    miami_winddir = miami_data["days"][x]["winddir"]
    miami_windgust = miami_data["days"][x]["windgust"]
    miami_windspeed = miami_data["days"][x]["windspeed"]

    full_data.append({"city": miami_city,
                  "date": miami_datetime,
                  "conditions": miami_conditions,
                  "description": miami_description,
                  "cloudcover": miami_cloudcover,
                  "dewpoint": miami_dew,
                  "pressure": miami_pressure,
                  "humidity": miami_humidity,
                  "uv_index": miami_uv_index,
                  "visibility": miami_visibility,
                  "feelslike": miami_feelslike,
                  "feelslikemin": miami_feelslikemin,
                  "feelslikemax": miami_feelslikemax,
                  "temp": miami_temp,
                  "tempmin": miami_tempmin,
                  "tempmax": miami_tempmax,
                  "precipitation": miami_precip,
                  "precipitation_type": miami_preciptype,
                  "wind_direction": miami_winddir,
                  "wind_speed": miami_windspeed,
                  "wind_gust": miami_windgust,
                  "severe_risk": miami_severerisk,
                  "moonphase": miami_moonphase,
                  "sunrise": miami_sunrise,
                  "sunset": miami_sunset
                  })

# %%
# Houston

for x in range(92): 
    houston_city = houston_data["address"]
    houston_cloudcover = houston_data["days"][x]["cloudcover"]
    houston_conditions = houston_data["days"][x]["conditions"]
    houston_datetime = houston_data["days"][x]["datetime"]
    houston_description = houston_data["days"][x]["description"]
    houston_dew = houston_data["days"][x]["dew"]
    houston_feelslike = houston_data["days"][x]["feelslike"]
    houston_feelslikemin = houston_data["days"][x]["feelslikemin"]
    houston_feelslikemax = houston_data["days"][x]["feelslikemax"]
    houston_humidity = houston_data["days"][x]["humidity"]
    houston_moonphase = houston_data["days"][x]["moonphase"]
    houston_precip = houston_data["days"][x]["precip"]
    houston_preciptype = houston_data["days"][x]["preciptype"]
    houston_pressure = houston_data["days"][x]["pressure"]
    houston_severerisk = houston_data["days"][x]["severerisk"]
    houston_sunrise = houston_data["days"][x]["sunrise"]
    houston_sunset = houston_data["days"][x]["sunset"]
    houston_temp = houston_data["days"][x]["temp"]
    houston_tempmax = houston_data["days"][x]["tempmax"]
    houston_tempmin = houston_data["days"][x]["tempmin"]
    houston_uv_index = houston_data["days"][x]["uvindex"]
    houston_visibility = houston_data["days"][x]["visibility"]
    houston_winddir = houston_data["days"][x]["winddir"]
    houston_windgust = houston_data["days"][x]["windgust"]
    houston_windspeed = houston_data["days"][x]["windspeed"]

    full_data.append({"city": houston_city,
                  "date": houston_datetime,
                  "conditions": houston_conditions,
                  "description": houston_description,
                  "cloudcover": houston_cloudcover,
                  "dewpoint": houston_dew,
                  "pressure": houston_pressure,
                  "humidity": houston_humidity,
                  "uv_index": houston_uv_index,
                  "visibility": houston_visibility,
                  "feelslike": houston_feelslike,
                  "feelslikemin": houston_feelslikemin,
                  "feelslikemax": houston_feelslikemax,
                  "temp": houston_temp,
                  "tempmin": houston_tempmin,
                  "tempmax": houston_tempmax,
                  "precipitation": houston_precip,
                  "precipitation_type": houston_preciptype,
                  "wind_direction": houston_winddir,
                  "wind_speed": houston_windspeed,
                  "wind_gust": houston_windgust,
                  "severe_risk": houston_severerisk,
                  "moonphase": houston_moonphase,
                  "sunrise": houston_sunrise,
                  "sunset": houston_sunset
                  })

# %%
# Kansas City

for x in range(92): 
    kansascity_city = kansascity_data["address"]
    kansascity_cloudcover = kansascity_data["days"][x]["cloudcover"]
    kansascity_conditions = kansascity_data["days"][x]["conditions"]
    kansascity_datetime = kansascity_data["days"][x]["datetime"]
    kansascity_description = kansascity_data["days"][x]["description"]
    kansascity_dew = kansascity_data["days"][x]["dew"]
    kansascity_feelslike = kansascity_data["days"][x]["feelslike"]
    kansascity_feelslikemin = kansascity_data["days"][x]["feelslikemin"]
    kansascity_feelslikemax = kansascity_data["days"][x]["feelslikemax"]
    kansascity_humidity = kansascity_data["days"][x]["humidity"]
    kansascity_moonphase = kansascity_data["days"][x]["moonphase"]
    kansascity_precip = kansascity_data["days"][x]["precip"]
    kansascity_preciptype = kansascity_data["days"][x]["preciptype"]
    kansascity_pressure = kansascity_data["days"][x]["pressure"]
    kansascity_severerisk = kansascity_data["days"][x]["severerisk"]
    kansascity_sunrise = kansascity_data["days"][x]["sunrise"]
    kansascity_sunset = kansascity_data["days"][x]["sunset"]
    kansascity_temp = kansascity_data["days"][x]["temp"]
    kansascity_tempmax = kansascity_data["days"][x]["tempmax"]
    kansascity_tempmin = kansascity_data["days"][x]["tempmin"]
    kansascity_uv_index = kansascity_data["days"][x]["uvindex"]
    kansascity_visibility = kansascity_data["days"][x]["visibility"]
    kansascity_winddir = kansascity_data["days"][x]["winddir"]
    kansascity_windgust = kansascity_data["days"][x]["windgust"]
    kansascity_windspeed = kansascity_data["days"][x]["windspeed"]

    full_data.append({"city": kansascity_city,
                  "date": kansascity_datetime,
                  "conditions": kansascity_conditions,
                  "description": kansascity_description,
                  "cloudcover": kansascity_cloudcover,
                  "dewpoint": kansascity_dew,
                  "pressure": kansascity_pressure,
                  "humidity": kansascity_humidity,
                  "uv_index": kansascity_uv_index,
                  "visibility": kansascity_visibility,
                  "feelslike": kansascity_feelslike,
                  "feelslikemin": kansascity_feelslikemin,
                  "feelslikemax": kansascity_feelslikemax,
                  "temp": kansascity_temp,
                  "tempmin": kansascity_tempmin,
                  "tempmax": kansascity_tempmax,
                  "precipitation": kansascity_precip,
                  "precipitation_type": kansascity_preciptype,
                  "wind_direction": kansascity_winddir,
                  "wind_speed": kansascity_windspeed,
                  "wind_gust": kansascity_windgust,
                  "severe_risk": kansascity_severerisk,
                  "moonphase": kansascity_moonphase,
                  "sunrise": kansascity_sunrise,
                  "sunset": kansascity_sunset
                  })

# %%
# Minneapolis
for x in range(92): 
    minneapolis_city = minneapolis_data["address"]
    minneapolis_cloudcover = minneapolis_data["days"][x]["cloudcover"]
    minneapolis_conditions = minneapolis_data["days"][x]["conditions"]
    minneapolis_datetime = minneapolis_data["days"][x]["datetime"]
    minneapolis_description = minneapolis_data["days"][x]["description"]
    minneapolis_dew = minneapolis_data["days"][x]["dew"]
    minneapolis_feelslike = minneapolis_data["days"][x]["feelslike"]
    minneapolis_feelslikemin = minneapolis_data["days"][x]["feelslikemin"]
    minneapolis_feelslikemax = minneapolis_data["days"][x]["feelslikemax"]
    minneapolis_humidity = minneapolis_data["days"][x]["humidity"]
    minneapolis_moonphase = minneapolis_data["days"][x]["moonphase"]
    minneapolis_precip = minneapolis_data["days"][x]["precip"]
    minneapolis_preciptype = minneapolis_data["days"][x]["preciptype"]
    minneapolis_pressure = minneapolis_data["days"][x]["pressure"]
    minneapolis_severerisk = minneapolis_data["days"][x]["severerisk"]
    minneapolis_sunrise = minneapolis_data["days"][x]["sunrise"]
    minneapolis_sunset = minneapolis_data["days"][x]["sunset"]
    minneapolis_temp = minneapolis_data["days"][x]["temp"]
    minneapolis_tempmax = minneapolis_data["days"][x]["tempmax"]
    minneapolis_tempmin = minneapolis_data["days"][x]["tempmin"]
    minneapolis_uv_index = minneapolis_data["days"][x]["uvindex"]
    minneapolis_visibility = minneapolis_data["days"][x]["visibility"]
    minneapolis_winddir = minneapolis_data["days"][x]["winddir"]
    minneapolis_windgust = minneapolis_data["days"][x]["windgust"]
    minneapolis_windspeed = minneapolis_data["days"][x]["windspeed"]

    full_data.append({"city": minneapolis_city,
                  "date": minneapolis_datetime,
                  "conditions": minneapolis_conditions,
                  "description": minneapolis_description,
                  "cloudcover": minneapolis_cloudcover,
                  "dewpoint": minneapolis_dew,
                  "pressure": minneapolis_pressure,
                  "humidity": minneapolis_humidity,
                  "uv_index": minneapolis_uv_index,
                  "visibility": minneapolis_visibility,
                  "feelslike": minneapolis_feelslike,
                  "feelslikemin": minneapolis_feelslikemin,
                  "feelslikemax": minneapolis_feelslikemax,
                  "temp": minneapolis_temp,
                  "tempmin": minneapolis_tempmin,
                  "tempmax": minneapolis_tempmax,
                  "precipitation": minneapolis_precip,
                  "precipitation_type": minneapolis_preciptype,
                  "wind_direction": minneapolis_winddir,
                  "wind_speed": minneapolis_windspeed,
                  "wind_gust": minneapolis_windgust,
                  "severe_risk": minneapolis_severerisk,
                  "moonphase": minneapolis_moonphase,
                  "sunrise": minneapolis_sunrise,
                  "sunset": minneapolis_sunset
                  })

# %%
# Denver

for x in range(92): 
    denver_city = denver_data["address"]
    denver_cloudcover = denver_data["days"][x]["cloudcover"]
    denver_conditions = denver_data["days"][x]["conditions"]
    denver_datetime = denver_data["days"][x]["datetime"]
    denver_description = denver_data["days"][x]["description"]
    denver_dew = denver_data["days"][x]["dew"]
    denver_feelslike = denver_data["days"][x]["feelslike"]
    denver_feelslikemin = denver_data["days"][x]["feelslikemin"]
    denver_feelslikemax = denver_data["days"][x]["feelslikemax"]
    denver_humidity = denver_data["days"][x]["humidity"]
    denver_moonphase = denver_data["days"][x]["moonphase"]
    denver_precip = denver_data["days"][x]["precip"]
    denver_preciptype = denver_data["days"][x]["preciptype"]
    denver_pressure = denver_data["days"][x]["pressure"]
    denver_severerisk = denver_data["days"][x]["severerisk"]
    denver_sunrise = denver_data["days"][x]["sunrise"]
    denver_sunset = denver_data["days"][x]["sunset"]
    denver_temp = denver_data["days"][x]["temp"]
    denver_tempmax = denver_data["days"][x]["tempmax"]
    denver_tempmin = denver_data["days"][x]["tempmin"]
    denver_uv_index = denver_data["days"][x]["uvindex"]
    denver_visibility = denver_data["days"][x]["visibility"]
    denver_winddir = denver_data["days"][x]["winddir"]
    denver_windgust = denver_data["days"][x]["windgust"]
    denver_windspeed = denver_data["days"][x]["windspeed"]

    full_data.append({"city": denver_city,
                  "date": denver_datetime,
                  "conditions": denver_conditions,
                  "description": denver_description,
                  "cloudcover": denver_cloudcover,
                  "dewpoint": denver_dew,
                  "pressure": denver_pressure,
                  "humidity": denver_humidity,
                  "uv_index": denver_uv_index,
                  "visibility": denver_visibility,
                  "feelslike": denver_feelslike,
                  "feelslikemin": denver_feelslikemin,
                  "feelslikemax": denver_feelslikemax,
                  "temp": denver_temp,
                  "tempmin": denver_tempmin,
                  "tempmax": denver_tempmax,
                  "precipitation": denver_precip,
                  "precipitation_type": denver_preciptype,
                  "wind_direction": denver_winddir,
                  "wind_speed": denver_windspeed,
                  "wind_gust": denver_windgust,
                  "severe_risk": denver_severerisk,
                  "moonphase": denver_moonphase,
                  "sunrise": denver_sunrise,
                  "sunset": denver_sunset
                  })

# %%
# San Francisco

for x in range(92): 
    sanfrancisco_city = sanfrancisco_data["address"]
    sanfrancisco_cloudcover = sanfrancisco_data["days"][x]["cloudcover"]
    sanfrancisco_conditions = sanfrancisco_data["days"][x]["conditions"]
    sanfrancisco_datetime = sanfrancisco_data["days"][x]["datetime"]
    sanfrancisco_description = sanfrancisco_data["days"][x]["description"]
    sanfrancisco_dew = sanfrancisco_data["days"][x]["dew"]
    sanfrancisco_feelslike = sanfrancisco_data["days"][x]["feelslike"]
    sanfrancisco_feelslikemin = sanfrancisco_data["days"][x]["feelslikemin"]
    sanfrancisco_feelslikemax = sanfrancisco_data["days"][x]["feelslikemax"]
    sanfrancisco_humidity = sanfrancisco_data["days"][x]["humidity"]
    sanfrancisco_moonphase = sanfrancisco_data["days"][x]["moonphase"]
    sanfrancisco_precip = sanfrancisco_data["days"][x]["precip"]
    sanfrancisco_preciptype = sanfrancisco_data["days"][x]["preciptype"]
    sanfrancisco_pressure = sanfrancisco_data["days"][x]["pressure"]
    sanfrancisco_severerisk = sanfrancisco_data["days"][x]["severerisk"]
    sanfrancisco_sunrise = sanfrancisco_data["days"][x]["sunrise"]
    sanfrancisco_sunset = sanfrancisco_data["days"][x]["sunset"]
    sanfrancisco_temp = sanfrancisco_data["days"][x]["temp"]
    sanfrancisco_tempmax = sanfrancisco_data["days"][x]["tempmax"]
    sanfrancisco_tempmin = sanfrancisco_data["days"][x]["tempmin"]
    sanfrancisco_uv_index = sanfrancisco_data["days"][x]["uvindex"]
    sanfrancisco_visibility = sanfrancisco_data["days"][x]["visibility"]
    sanfrancisco_winddir = sanfrancisco_data["days"][x]["winddir"]
    sanfrancisco_windgust = sanfrancisco_data["days"][x]["windgust"]
    sanfrancisco_windspeed = sanfrancisco_data["days"][x]["windspeed"]

    full_data.append({"city": sanfrancisco_city,
                  "date": sanfrancisco_datetime,
                  "conditions": sanfrancisco_conditions,
                  "description": sanfrancisco_description,
                  "cloudcover": sanfrancisco_cloudcover,
                  "dewpoint": sanfrancisco_dew,
                  "pressure": sanfrancisco_pressure,
                  "humidity": sanfrancisco_humidity,
                  "uv_index": sanfrancisco_uv_index,
                  "visibility": sanfrancisco_visibility,
                  "feelslike": sanfrancisco_feelslike,
                  "feelslikemin": sanfrancisco_feelslikemin,
                  "feelslikemax": sanfrancisco_feelslikemax,
                  "temp": sanfrancisco_temp,
                  "tempmin": sanfrancisco_tempmin,
                  "tempmax": sanfrancisco_tempmax,
                  "precipitation": sanfrancisco_precip,
                  "precipitation_type": sanfrancisco_preciptype,
                  "wind_direction": sanfrancisco_winddir,
                  "wind_speed": sanfrancisco_windspeed,
                  "wind_gust": sanfrancisco_windgust,
                  "severe_risk": sanfrancisco_severerisk,
                  "moonphase": sanfrancisco_moonphase,
                  "sunrise": sanfrancisco_sunrise,
                  "sunset": sanfrancisco_sunset
                  })

# %%
# Seattle

for x in range(92): 
    seattle_city = seattle_data["address"]
    seattle_cloudcover = seattle_data["days"][x]["cloudcover"]
    seattle_conditions = seattle_data["days"][x]["conditions"]
    seattle_datetime = seattle_data["days"][x]["datetime"]
    seattle_description = seattle_data["days"][x]["description"]
    seattle_dew = seattle_data["days"][x]["dew"]
    seattle_feelslike = seattle_data["days"][x]["feelslike"]
    seattle_feelslikemin = seattle_data["days"][x]["feelslikemin"]
    seattle_feelslikemax = seattle_data["days"][x]["feelslikemax"]
    seattle_humidity = seattle_data["days"][x]["humidity"]
    seattle_moonphase = seattle_data["days"][x]["moonphase"]
    seattle_precip = seattle_data["days"][x]["precip"]
    seattle_preciptype = seattle_data["days"][x]["preciptype"]
    seattle_pressure = seattle_data["days"][x]["pressure"]
    seattle_severerisk = seattle_data["days"][x]["severerisk"]
    seattle_sunrise = seattle_data["days"][x]["sunrise"]
    seattle_sunset = seattle_data["days"][x]["sunset"]
    seattle_temp = seattle_data["days"][x]["temp"]
    seattle_tempmax = seattle_data["days"][x]["tempmax"]
    seattle_tempmin = seattle_data["days"][x]["tempmin"]
    seattle_uv_index = seattle_data["days"][x]["uvindex"]
    seattle_visibility = seattle_data["days"][x]["visibility"]
    seattle_winddir = seattle_data["days"][x]["winddir"]
    seattle_windgust = seattle_data["days"][x]["windgust"]
    seattle_windspeed = seattle_data["days"][x]["windspeed"]

    full_data.append({"city": seattle_city,
                  "date": seattle_datetime,
                  "conditions": seattle_conditions,
                  "description": seattle_description,
                  "cloudcover": seattle_cloudcover,
                  "dewpoint": seattle_dew,
                  "pressure": seattle_pressure,
                  "humidity": seattle_humidity,
                  "uv_index": seattle_uv_index,
                  "visibility": seattle_visibility,
                  "feelslike": seattle_feelslike,
                  "feelslikemin": seattle_feelslikemin,
                  "feelslikemax": seattle_feelslikemax,
                  "temp": seattle_temp,
                  "tempmin": seattle_tempmin,
                  "tempmax": seattle_tempmax,
                  "precipitation": seattle_precip,
                  "precipitation_type": seattle_preciptype,
                  "wind_direction": seattle_winddir,
                  "wind_speed": seattle_windspeed,
                  "wind_gust": seattle_windgust,
                  "severe_risk": seattle_severerisk,
                  "moonphase": seattle_moonphase,
                  "sunrise": seattle_sunrise,
                  "sunset": seattle_sunset
                  })

# %%
# Phoenix

for x in range(92): 
    phoenix_city = phoenix_data["address"]
    phoenix_cloudcover = phoenix_data["days"][x]["cloudcover"]
    phoenix_conditions = phoenix_data["days"][x]["conditions"]
    phoenix_datetime = phoenix_data["days"][x]["datetime"]
    phoenix_description = phoenix_data["days"][x]["description"]
    phoenix_dew = phoenix_data["days"][x]["dew"]
    phoenix_feelslike = phoenix_data["days"][x]["feelslike"]
    phoenix_feelslikemin = phoenix_data["days"][x]["feelslikemin"]
    phoenix_feelslikemax = phoenix_data["days"][x]["feelslikemax"]
    phoenix_humidity = phoenix_data["days"][x]["humidity"]
    phoenix_moonphase = phoenix_data["days"][x]["moonphase"]
    phoenix_precip = phoenix_data["days"][x]["precip"]
    phoenix_preciptype = phoenix_data["days"][x]["preciptype"]
    phoenix_pressure = phoenix_data["days"][x]["pressure"]
    phoenix_severerisk = phoenix_data["days"][x]["severerisk"]
    phoenix_sunrise = phoenix_data["days"][x]["sunrise"]
    phoenix_sunset = phoenix_data["days"][x]["sunset"]
    phoenix_temp = phoenix_data["days"][x]["temp"]
    phoenix_tempmax = phoenix_data["days"][x]["tempmax"]
    phoenix_tempmin = phoenix_data["days"][x]["tempmin"]
    phoenix_uv_index = phoenix_data["days"][x]["uvindex"]
    phoenix_visibility = phoenix_data["days"][x]["visibility"]
    phoenix_winddir = phoenix_data["days"][x]["winddir"]
    phoenix_windgust = phoenix_data["days"][x]["windgust"]
    phoenix_windspeed = phoenix_data["days"][x]["windspeed"]

    full_data.append({"city": phoenix_city,
                  "date": phoenix_datetime,
                  "conditions": phoenix_conditions,
                  "description": phoenix_description,
                  "cloudcover": phoenix_cloudcover,
                  "dewpoint": phoenix_dew,
                  "pressure": phoenix_pressure,
                  "humidity": phoenix_humidity,
                  "uv_index": phoenix_uv_index,
                  "visibility": phoenix_visibility,
                  "feelslike": phoenix_feelslike,
                  "feelslikemin": phoenix_feelslikemin,
                  "feelslikemax": phoenix_feelslikemax,
                  "temp": phoenix_temp,
                  "tempmin": phoenix_tempmin,
                  "tempmax": phoenix_tempmax,
                  "precipitation": phoenix_precip,
                  "precipitation_type": phoenix_preciptype,
                  "wind_direction": phoenix_winddir,
                  "wind_speed": phoenix_windspeed,
                  "wind_gust": phoenix_windgust,
                  "severe_risk": phoenix_severerisk,
                  "moonphase": phoenix_moonphase,
                  "sunrise": phoenix_sunrise,
                  "sunset": phoenix_sunset
                  })

# %%
# Convert to DataFrame and export to csv

full_data_df = pd.DataFrame(full_data)
full_data_df.head()
full_data_df.to_csv("../output_data/full_data.csv")

# %%
full_data_df.dtypes
# Out:
# city                   object
# date                   object
# conditions             object
# description            object
# cloudcover            float64
# dewpoint              float64
# pressure              float64
# humidity              float64
# uv_index              float64
# visibility            float64
# feelslike             float64
# feelslikemin          float64
# feelslikemax          float64
# temp                  float64
# tempmin               float64
# tempmax               float64
# precipitation         float64
# precipitation_type     object
# wind_direction        float64
# wind_speed            float64
# wind_gust             float64
# severe_risk           float64
# moonphase             float64
# sunrise                object
# sunset                 object
# dtype: object

# %%
# Split into smaller DataFrames and export to csv

# Temp and Humidity

temp_humidity_df = full_data_df[["city", "date", "humidity", "feelslike", "feelslikemin", "feelslikemax", "temp", "tempmin", "tempmax"]]
temp_humidity_df.to_csv("../output_data/temp_humidity.csv")
temp_humidity_df.head()
# Out:
#       city        date  humidity  feelslike  feelslikemin  feelslikemax  temp  \
# 0  Chicago  2023-05-01      72.9       36.7          32.0          44.3  44.0
# 1  Chicago  2023-05-02      53.9       43.4          35.7          54.6  48.1
# 2  Chicago  2023-05-03      60.4       44.3          34.5          55.4  47.6
# 3  Chicago  2023-05-04      48.4       56.9          40.6          71.6  57.3
# 4  Chicago  2023-05-05      36.0       67.5          55.8          77.5  67.5
#
#    tempmin  tempmax
# 0     40.6     49.9
# 1     42.9     54.6
# 2     40.8     55.4
# 3     41.8     71.6
# 4     55.8     77.5

# %%
# Precipitation

precipitation_df = full_data_df[["city", "date", "precipitation", "precipitation_type", "severe_risk"]]
precipitation_df.to_csv("../output_data/precipitation.csv")
precipitation_df.head()
# Out:
#       city        date  precipitation precipitation_type  severe_risk
# 0  Chicago  2023-05-01          0.068             [rain]         10.0
# 1  Chicago  2023-05-02          0.000               None         10.0
# 2  Chicago  2023-05-03          0.000               None         10.0
# 3  Chicago  2023-05-04          0.000               None         10.0
# 4  Chicago  2023-05-05          0.000               None         10.0

# %%
# Wind

wind_df = full_data_df[["city", "date", "wind_direction", "wind_speed", "wind_gust"]]
wind_df.to_csv("../output_data/wind.csv")
wind_df.head()
# Out:
#       city        date  wind_direction  wind_speed  wind_gust
# 0  Chicago  2023-05-01           304.2        21.8       35.5
# 1  Chicago  2023-05-02           327.9        20.8       31.1
# 2  Chicago  2023-05-03             6.1        16.5       26.8
# 3  Chicago  2023-05-04           175.3        13.3       21.9
# 4  Chicago  2023-05-05           171.8        18.2       33.3

# %%
# Sun and Moon

sun_moon_df = full_data_df[["city", "date", "moonphase", "sunrise", "sunset"]]
sun_moon_df.to_csv("../output_data/sun_moon.csv")
sun_moon_df.head()
# Out:
#       city        date  moonphase   sunrise    sunset
# 0  Chicago  2023-05-01       0.37  05:46:59  19:49:04
# 1  Chicago  2023-05-02       0.40  05:45:40  19:50:09
# 2  Chicago  2023-05-03       0.43  05:44:22  19:51:14
# 3  Chicago  2023-05-04       0.47  05:43:06  19:52:19
# 4  Chicago  2023-05-05       0.50  05:41:50  19:53:24

# %%
# Descriptions

descriptions_df = full_data_df[["city", "date", "conditions", "description"]]
descriptions_df.to_csv("../output_data/descriptions.csv")
descriptions_df.head()
# Out:
#       city        date        conditions  \
# 0  Chicago  2023-05-01    Rain, Overcast
# 1  Chicago  2023-05-02          Overcast
# 2  Chicago  2023-05-03  Partially cloudy
# 3  Chicago  2023-05-04  Partially cloudy
# 4  Chicago  2023-05-05  Partially cloudy
#
#                                          description
# 0  Cloudy skies throughout the day with rain in t...
# 1                   Cloudy skies throughout the day.
# 2                         Clearing in the afternoon.
# 3                  Partly cloudy throughout the day.
# 4                  Partly cloudy throughout the day.

# %%
# Other Data

other_conditions_df = full_data_df[["city", "date", "cloudcover", "dewpoint", "pressure", "uv_index", "visibility"]]
other_conditions_df.to_csv("../output_data/other_conditions.csv")
other_conditions_df.head()
# Out:
#       city        date  cloudcover  dewpoint  pressure  uv_index  visibility
# 0  Chicago  2023-05-01        98.8      35.7     997.4       2.0         9.4
# 1  Chicago  2023-05-02        95.2      32.0    1002.8       7.0         9.9
# 2  Chicago  2023-05-03        59.8      34.4    1012.9       9.0         9.9
# 3  Chicago  2023-05-04        30.6      36.0    1015.0       9.0         9.9
# 4  Chicago  2023-05-05        54.4      38.6    1015.9       8.0         9.9
